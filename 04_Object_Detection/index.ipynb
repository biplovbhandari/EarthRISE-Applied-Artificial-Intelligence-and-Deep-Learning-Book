# %% [raw]
# ---
# author: "Norah Smith"
# ---

# %% [markdown]
# # Object Detection

# %%
# Print out the Python version used by this environment.
import sys

print(f'{sys.version=}')

# %% [markdown]
# {{< lipsum >}}
