# %% [raw]
# ---
# author: "Dr X "
# ---

# %% [raw]
# # Data Preparation

# %%
# Print out the Python version used by this environment.
import sys

print(f'{sys.version=}')

# %% [markdown]
# Insert text here
#
# {{< lipsum >}}
